# %%
from deepface import DeepFace
import os
import numpy as np
import cv2
# Out:
# 24-08-29 02:09:03 - Directory /home/ehtisham/.deepface has been created
# 24-08-29 02:09:03 - Directory /home/ehtisham/.deepface/weights has been created

# %%
dataset_path = "detection_models/images/"

# %%
images_array = []
for f in os.listdir(dataset_path):
    folder = os.path.join(dataset_path,f)
    for img in os.listdir(folder):
        # print(img)
        img = os.path.join(folder,img)
        img = cv2.imread(img)
        images_array.append(images_array)

# %%
len(images_array)
# Out:
# 24

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
  "GhostFaceNet",
]

embeddings = []
for img in images_array:
    #face recognition
    face = DeepFace.find(
                # img,
                img_path = "detection_models/images/1628/1644.jpg",
                db_path = "detection_models/images/1628", 
                model_name = models[1],
                detector_backend="opencv"
                )
# Out:
# 24-08-29 02:21:25 - Found 6 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 17
#      14 embeddings = []
#      15 for img in images_array:
#      16     #face recognition
# ---> 17     face = DeepFace.find(
#      18                 # img,
#      19                 img_path = "detection_models/images/1628/1644.jpg",
#      20                 db_path = "detection_models/images/1628",
#      21                 model_name = models[1],
#      22                 detector_backend="opencv"
#      23                 )
#
# File ~/Documents/Face_recognition_django/envs/lib/python3.9/site-packages/deepface/DeepFace.py:342, in find(img_path, db_path, model_name, distance_metric, enforce_detection, detector_backend, align, expand_percentage, threshold, normalization, silent, refresh_database, anti_spoofing)
#     265 def find(
#     266     img_path: Union[str, np.ndarray],
#     267     db_path: str,
#    (...)
#     278     anti_spoofing: bool = False,
#     279 ) -> List[pd.DataFrame]:
#     280     """
#     281     Identify individuals in a database
#     282     Args:
#    (...)
#     340                 specified model and distance metric
#     341     """
# --> 342     return recognition.find(
#     343         img_path=img_path,
#     344         db_path=db_path,
#     345         model_name=model_name,
#     346         distance_metric=distance_metric,
#     347         enforce_detection=enforce_detection,
#     348         detector_backend=detector_backend,
#     349         align=align,
#     350         expand_percentage=expand_percentage,
#     351         threshold=threshold,
#     352         normalization=normalization,
#     353         silent=silent,
#     354         refresh_database=refresh_database,
#     355         anti_spoofing=anti_spoofing,
#     356     )
#
# File ~/Documents/Face_recognition_django/envs/lib/python3.9/site-packages/deepface/modules/recognition.py:205, in find(img_path, db_path, model_name, distance_metric, enforce_detection, detector_backend, align, expand_percentage, threshold, normalization, silent, refresh_database, anti_spoofing)
#     203 # find representations for new images
#     204 if len(new_images) > 0:
# --> 205     representations += __find_bulk_embeddings(
#     206         employees=new_images,
#     207         model_name=model_name,
#     208         detector_backend=detector_backend,
#     209         enforce_detection=enforce_detection,
#     210         align=align,
#     211         expand_percentage=expand_percentage,
#     212         normalization=normalization,
#     213         silent=silent,
#     214     )  # add new images
#     215     must_save_pickle = True
#     217 if must_save_pickle:
#
# File ~/Documents/Face_recognition_django/envs/lib/python3.9/site-packages/deepface/modules/recognition.py:362, in __find_bulk_embeddings(employees, model_name, detector_backend, enforce_detection, align, expand_percentage, normalization, silent)
#     359 file_hash = image_utils.find_image_hash(employee)
#     361 try:
# --> 362     img_objs = detection.extract_faces(
#     363         img_path=employee,
#     364         detector_backend=detector_backend,
#     365         grayscale=False,
#     366         enforce_detection=enforce_detection,
#     367         align=align,
#     368         expand_percentage=expand_percentage,
#     369     )
#     371 except ValueError as err:
#     372     logger.error(f"Exception while extracting faces from {employee}: {str(err)}")
#
# File ~/Documents/Face_recognition_django/envs/lib/python3.9/site-packages/deepface/modules/detection.py:95, in extract_faces(img_path, detector_backend, enforce_detection, align, expand_percentage, grayscale, color_face, normalize_face, anti_spoofing)
#      93     face_objs = [DetectedFace(img=img, facial_area=base_region, confidence=0)]
#      94 else:
# ---> 95     face_objs = detect_faces(
#      96         detector_backend=detector_backend,
#      97         img=img,
#      98         align=align,
#      99         expand_percentage=expand_percentage,
#     100     )
#     102 # in case of no face found
#     103 if len(face_objs) == 0 and enforce_detection is True:
#
# File ~/Documents/Face_recognition_django/envs/lib/python3.9/site-packages/deepface/modules/detection.py:206, in detect_faces(detector_backend, img, align, expand_percentage)
#     181 """
#     182 Detect face(s) from a given image
#     183 Args:
#    (...)
#     202     - confidence (float): The confidence score associated with the detected face.
#     203 """
#     204 height, width, _ = img.shape
# --> 206 face_detector: Detector = modeling.build_model(
#     207     task="face_detector", model_name=detector_backend
#     208 )
#     210 # validate expand percentage score
#     211 if expand_percentage < 0:
#
# AttributeError: module 'deepface.modules.modeling' has no attribute 'build_model'
