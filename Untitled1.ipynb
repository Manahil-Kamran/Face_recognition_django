# %%
import csv
import os
import gc
import psutil
import random
import numpy as np
import cv2
from PIL import Image
import torch
from my_utils.base import Resnet50
from my_utils.transform import make_transform
from django.utils.timezone import now
from myapp.models import PersonRegistration, FaceCoding
import warnings
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       7 import cv2
#       8 from PIL import Image
# ----> 9 import torch
#      10 from my_utils.base import Resnet50
#      11 from my_utils.transform import make_transform
#
# ModuleNotFoundError: No module named 'torch'
